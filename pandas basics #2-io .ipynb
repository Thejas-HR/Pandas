# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')

# %%
df = pd.read_excel('F:\Portfolio Project\Movie Data Starter Project.xlsx')

# %%
df.head()
# Out:
#           Movie Title Release Date  \
# 0    The Devil Inside   2012-01-06
# 1           Red Tails   2012-01-20
# 2  Declaration of War   2012-01-27
# 3      Man on a Ledge   2012-01-27
# 4   One for the Money   2012-01-27
#
#                                        Wikipedia URL Genre (1) Genre (2)  \
# 0  https://en.wikipedia.org/wiki/The_Devil_Inside...    Horror     Drama
# 1            https://en.wikipedia.org/wiki/Red_Tails     Drama       NaN
# 2  https://en.wikipedia.org/wiki/Declaration_of_W...   Romance     Drama
# 3       https://en.wikipedia.org/wiki/Man_on_a_Ledge    Action     Drama
# 4  https://en.wikipedia.org/wiki/One_for_the_Mone...     Crime   Romance
#
#           Director (1) Director (2)                     Cast (1)  \
# 0   William Brent Bell          NaN                Suzan Crowley
# 1    Anthony Hemingway          NaN             Cuba Gooding Jr.
# 2     Valérie Donzelli          NaN  Valérie Donzelli (director)
# ...

# %%
df.to_csv('movie dataset.csv')

# %%
df.to_csv('movie_dataset2.csv', header = True)

# %%
df =pd.read_csv('movie_dataset2.csv')

# %%
df
# Out:
#      Unnamed: 0  Unnamed: 0.1    0          The Devil Inside  2012-01-06  \
# 0             0             0    1                 Red Tails  2012-01-20
# 1             1             1    2        Declaration of War  2012-01-27
# 2             2             2    3            Man on a Ledge  2012-01-27
# 3             3             3    4         One for the Money  2012-01-27
# 4             4             4    5                  The Grey  2012-01-27
# ..          ...           ...  ...                       ...         ...
# 502         502           502  503  Kubo and the Two Strings  2016-08-19
# 503         503           503  504                  War Dogs  2016-08-19
# 504         504           504  505             Don't Breathe  2016-08-26
# 505         505           505  506            Hands of Stone  2016-08-26
# 506         506           506  507    Mechanic: Resurrection  2016-08-26
#
#     https://en.wikipedia.org/wiki/The_Devil_Inside_(film)     Horror    Drama  \
# ...

# %%
# renaming cols

df.rename(columns={'existing name' : 'new name'})
